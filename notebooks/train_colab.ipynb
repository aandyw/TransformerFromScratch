# %%
# !git clone https://github.com/aandyw/TransformerFromScratch.git
# Out:
# Cloning into 'TransformerFromScratch'...
# remote: Enumerating objects: 236, done.
# remote: Counting objects: 100% (236/236), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 236 (delta 121), reused 156 (delta 53), pack-reused 0 (from 0)
# Receiving objects: 100% (236/236), 682.41 KiB | 11.57 MiB/s, done.
# Resolving deltas: 100% (121/121), done.

# %%
# %%capture
# %cd TransformerFromScratch
# !pip install -r requirements.txt

# %%
# %cd transformer/
# Out:
# /kaggle/working/TransformerFromScratch/transformer

# %%
from config import get_config
from train import Trainer

config = get_config({
    "batch_size": 16
})
trainer = Trainer(config)
trainer.train()
# Out:
# Using device: cuda
# README.md:   0%|          | 0.00/28.1k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/5.73M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Max length of source sentence: 309
# Max length of source sentence: 274
# Processing epoch 00: 100%|██████████| 1819/1819 [14:33<00:00,  2.08it/s, Loss=5.741]
# Processing epoch 01: 100%|██████████| 1819/1819 [14:32<00:00,  2.09it/s, Loss=5.115]
# Processing epoch 02: 100%|██████████| 1819/1819 [14:32<00:00,  2.09it/s, Loss=5.137]
# Processing epoch 03: 100%|██████████| 1819/1819 [14:31<00:00,  2.09it/s, Loss=4.988]
# Processing epoch 04:  91%|█████████ | 1654/1819 [13:12<01:19,  2.09it/s, Loss=4.929]
