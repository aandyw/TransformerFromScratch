# %%
# !git clone https://github.com/aandyw/TransformerFromScratch.git
# Out:
# Cloning into 'TransformerFromScratch'...
# remote: Enumerating objects: 254, done.
# remote: Counting objects: 100% (254/254), done.
# remote: Compressing objects: 100% (188/188), done.
# remote: Total 254 (delta 131), reused 170 (delta 59), pack-reused 0 (from 0)
# Receiving objects: 100% (254/254), 948.08 KiB | 20.17 MiB/s, done.
# Resolving deltas: 100% (131/131), done.

# %%
# %%capture
# %cd TransformerFromScratch
# !pip install -r requirements.txt

# %%
# %cd transformer/
# Out:
# /kaggle/working/TransformerFromScratch/transformer

# %%
from config import get_config
from train import Trainer

config = get_config({
    "batch_size": 16,
    "num_epochs": 20
})
trainer = Trainer(config)
trainer.train()
# Out:
# Using device: cuda
# README.md:   0%|          | 0.00/28.1k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/5.73M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Max length of source sentence: 309
# Max length of source sentence: 274
# ...
# Processing epoch 04: 100%|██████████| 1819/1819 [14:33<00:00,  2.08it/s, Loss=4.702]
# --------------------------------------------------------------------------------
# SOURCE: After having carefully examined and sounded the agitated invalid, who was stupefied with shame, the celebrity, having carefully washed his hands, stood in the drawing-room talking to the Prince.
# TARGET: Dopo aver visitato e tastato attentamente l’ammalata, smarrita e stordita per la vergogna, il medico famoso, lavatesi accuratamente le mani, rimase in piedi nel salotto a parlare col principe.
# ...
